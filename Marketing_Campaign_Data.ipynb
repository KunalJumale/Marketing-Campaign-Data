# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("C:/Users/jumal/OneDrive/Desktop/Data Analyst/Project/Marketing_Campaign_Data.csv")
df
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Display top 5 rows dataset
df.head(3)
# Out:
#   campaign_id                 campaign_name        channel  start_date  \
# 0    CMP00001             Product Launch My  Search Engine  2023-06-02
# 1    CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2    CMP00003  Brand Awareness Relationship          Radio  2023-10-18
#
#      end_date    budget  leads_generated  conversion_rate    revenue  \
# 0  2024-08-17  53108.27             4022             7.41  140155.63
# 1  2025-07-29  27767.47             2997             0.79   22088.26
# 2  2024-01-12  30913.46             3638             9.00   90698.04
#
#       status  impressions  clicks    ctr  engagement_score campaign_manager  \
# 0  Completed       122958   35250  28.67              4.32       Ravi Kumar
# 1    Planned       672155   25921   3.86              4.33       Amit Mehta
# 2  Completed       132932   26760  20.13              1.47       Amit Mehta
#
#    notes
# 0    NaN
# 1    NaN
# 2    NaN

# %%
# last 5 rows data from dataset
df.tail(3)
# Out:
#      campaign_id            campaign_name        channel  start_date  \
# 2247    CMP02248   Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249   Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250  Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# 2247  2023-07-08  87487.82             2190             6.50   10985.82
# 2248  2024-02-18  91298.48             1740            14.01   64296.78
# 2249  2024-08-19  84641.04             2493             2.17  108961.63
#
#          status  impressions  clicks    ctr  engagement_score  \
# 2247  Completed       324390    1619   0.50              1.81
# 2248    Ongoing       264579   22261   8.41              9.20
# 2249    Planned       230947   40803  17.67              1.05
#
#      campaign_manager  notes
# 2247    Vikram Chopra    NaN
# 2248      Kiran Desai    NaN
# 2249     Sanjay Kumar    NaN

# %%
# Display summary 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2250 entries, 0 to 2249
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   campaign_id       2250 non-null   object
#  1   campaign_name     2250 non-null   object
#  2   channel           2250 non-null   object
#  3   start_date        2250 non-null   object
#  4   end_date          2250 non-null   object
#  5   budget            2250 non-null   float64
#  6   leads_generated   2250 non-null   int64
#  7   conversion_rate   2250 non-null   float64
#  8   revenue           2250 non-null   float64
#  9   status            2250 non-null   object
#  10  impressions       2250 non-null   int64
#  11  clicks            2250 non-null   int64
#  12  ctr               2250 non-null   float64
#  13  engagement_score  2250 non-null   float64
#  14  campaign_manager  2250 non-null   object
#  15  notes             0 non-null      float64
# ...

# %%
# display only Numaricals dataset
df.describe()
# Out:
#              budget  leads_generated  conversion_rate        revenue  \
# count   2250.000000      2250.000000      2250.000000    2250.000000
# mean   51253.920240      2590.892444         7.675898   71410.406920
# std    28764.280391      1436.573719         4.167988   55240.972356
# min     1016.870000        11.000000         0.510000     220.810000
# 25%    27249.007500      1375.250000         4.040000   25403.965000
# 50%    51389.385000      2601.000000         7.505000   58372.360000
# 75%    76147.630000      3853.500000        11.385000  106309.885000
# max    99978.250000      5000.000000        15.000000  247170.160000
#
#          impressions        clicks          ctr  engagement_score  notes
# count    2250.000000   2250.000000  2250.000000       2250.000000    0.0
# mean   494839.709778  24843.719111    11.645111          5.430378    NaN
# std    292002.815405  14317.555621    19.600406          2.593875    NaN
# ...

# %%
# check type of dataset
df.dtypes
# Out:
# campaign_id          object
# campaign_name        object
# channel              object
# start_date           object
# end_date             object
# budget              float64
# leads_generated       int64
# conversion_rate     float64
# revenue             float64
# status               object
# impressions           int64
# clicks                int64
# ctr                 float64
# engagement_score    float64
# campaign_manager     object
# notes               float64
# dtype: object

# %%
# Check dimension of dataframe
df.ndim
# Out:
# 2

# %%
# Lets check all columns present in dataframe
df.columns
# Out:
# Index(['campaign_id', 'campaign_name', 'channel', 'start_date', 'end_date',
#        'budget', 'leads_generated', 'conversion_rate', 'revenue', 'status',
#        'impressions', 'clicks', 'ctr', 'engagement_score', 'campaign_manager',
#        'notes'],
#       dtype='object')

# %%
# Identify duplicate records in Rows
df.duplicated().sum()
# Out:
# 0

# %%
# Check Duplicate values in Columns
df["leads_generated"].duplicated().sum()
# Out:
# 434

# %%
# Find shape of dataframe i.e number of rows and columns.
df.shape
# Out:
# (2250, 16)

# %%
# delete all duplicate rows
df.drop_duplicates()
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# delete duplicate columns
df.drop_duplicates("leads_generated")
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# find missing data/values/null values
df.isnull().sum()
# Out:
# campaign_id            0
# campaign_name          0
# channel                0
# start_date             0
# end_date               0
# budget                 0
# leads_generated        0
# conversion_rate        0
# revenue                0
# status                 0
# impressions            0
# clicks                 0
# ctr                    0
# engagement_score       0
# campaign_manager       0
# notes               2250
# dtype: int64

# %%
# How can you find the total number of missing values in the leads_generated column of a DataFrame df?

df["leads_generated"].isnull().sum()
# Out:
# 0

# %%
df.dropna(axis=0, inplace=False)
# Out:
# Empty DataFrame
# Columns: [campaign_id, campaign_name, channel, start_date, end_date, budget, leads_generated, conversion_rate, revenue, status, impressions, clicks, ctr, engagement_score, campaign_manager, notes]
# Index: []

# %%
# How can you remove columns from a pandas DataFrame that contain any missing values without modifying the original DataFrame?

df.dropna(axis=1, inplace=False)
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
df.ffill(inplace=False)
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
df.bfill(inplace=False)
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
df["leads_generated"].mean()
# Out:
# 2590.8924444444447

# %%
df["leads_generated"].median()
# Out:
# 2601.0

# %%
df["leads_generated"].mode()
# Out:
# 0     886
# 1    3438
# 2    3584
# 3    4032
# Name: leads_generated, dtype: int64

# %%
# You are given a DataFrame df that contains some missing (NaN) values. You want to replace all NaN values in the DataFrame with the integer 2601.
df.replace(np.NaN, 2601)
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# You are given a DataFrame df with 2250 rows. How would you create a new DataFrame by removing the rows at indexes 0, 2, 4, 2244, and 2247, without affecting the original DataFrame?

df.drop([0,2,4,2247,2244], axis=0, inplace=False)
# Out:
#      campaign_id             campaign_name        channel  start_date  \
# 1       CMP00002  Product Launch Candidate          Radio  2024-01-26
# 3       CMP00004    Discount Offer Hundred   Social Media  2024-03-25
# 5       CMP00006     Event Promotion Study          Email  2024-04-09
# 6       CMP00007    Seasonal Campaign Year             TV  2023-07-14
# 7       CMP00008       Brand Awareness Car  Search Engine  2023-06-20
# ...          ...                       ...            ...         ...
# 2243    CMP02244     Brand Awareness After             TV  2024-02-17
# 2245    CMP02246      Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247      Discount Offer Think  Search Engine  2023-08-07
# 2248    CMP02249    Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250   Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# You have a DataFrame df with multiple columns. Write a Python command to display the first 5 rows of only the "campaign_name" and "channel" columns.

df[["campaign_name", "channel"]].head(5)
# Out:
#                   campaign_name        channel
# 0             Product Launch My  Search Engine
# 1      Product Launch Candidate          Radio
# 2  Brand Awareness Relationship          Radio
# 3        Discount Offer Hundred   Social Media
# 4          Event Promotion Help      Newspaper

# %%
#Q1. Given a DataFrame df with multiple columns, write the code to create a new DataFrame by dropping the columns "campaign_name", "end_date", and "conversion_rate" without modifying the original DataFrame.

df.drop(["campaign_name", "end_date", "conversion_rate"], axis=1, inplace=False)
# Out:
#      campaign_id        channel  start_date    budget  leads_generated  \
# 0       CMP00001  Search Engine  2023-06-02  53108.27             4022
# 1       CMP00002          Radio  2024-01-26  27767.47             2997
# 2       CMP00003          Radio  2023-10-18  30913.46             3638
# 3       CMP00004   Social Media  2024-03-25  62950.55             2559
# 4       CMP00005      Newspaper  2023-07-28  82191.05             4368
# ...          ...            ...         ...       ...              ...
# 2245    CMP02246          Radio  2024-02-20  86830.51              265
# 2246    CMP02247  Search Engine  2023-08-07   9954.56              923
# 2247    CMP02248  Search Engine  2023-06-22  87487.82             2190
# 2248    CMP02249          Radio  2024-01-08  91298.48             1740
# 2249    CMP02250             TV  2024-03-11  84641.04             2493
#
#         revenue     status  impressions  clicks    ctr  engagement_score  \
# ...

# %%
# How can you display the first 5 rows of only the conversion_rate and channel columns from a DataFrame named df?

df[["conversion_rate", "channel"]].head(5)
# Out:
#    conversion_rate        channel
# 0             7.41  Search Engine
# 1             0.79          Radio
# 2             9.00          Radio
# 3             7.27   Social Media
# 4             8.57      Newspaper

# %%
bar=df[["conversion_rate", "channel"]].head(5)
plt.bar(bar["conversion_rate"], bar["channel"])
plt.xlabel("conversion_rate")
plt.ylabel("channel")
plt.title("Barplot")
plt.show()

# %%
# Write a Python Pandas command to retrieve the last 5 rows of only the "ctr" and "campaign_manager" columns.

df[["ctr" ,"campaign_manager"]].tail(5)
# Out:
#         ctr campaign_manager
# 2245   5.08     Rahul Sharma
# 2246   1.02       Amit Reddy
# 2247   0.50    Vikram Chopra
# 2248   8.41      Kiran Desai
# 2249  17.67     Sanjay Kumar

# %%
pi=df[["ctr" ,"campaign_manager"]].tail(5)
plt.pie(pi["ctr"], labels=pi["campaign_manager"], autopct="%0.0f%%")
plt.show()

# %%
df[25:28]
# Out:
#    campaign_id            campaign_name     channel  start_date    end_date  \
# 25    CMP00026       Event Promotion Be  Influencer  2023-09-02  2025-02-11
# 26    CMP00027     Discount Offer Could  Influencer  2024-02-12  2025-01-30
# 27    CMP00028  Seasonal Campaign Dream       Radio  2023-09-10  2024-11-14
#
#       budget  leads_generated  conversion_rate    revenue     status  \
# 25  37133.25             1381             1.59   60796.25  Completed
# 26  36908.97             3247            11.25  145718.78    Ongoing
# 27  69064.20             1006             3.34    6812.16    Planned
#
#     impressions  clicks    ctr  engagement_score campaign_manager  notes
# 25       777997   21830   2.81              4.31     Sanjay Kumar    NaN
# 26       200041   21527  10.76              1.52     Rahul Sharma    NaN
# 27       792743   35296   4.45              2.00      Neha Sharma    NaN

# %%
df.loc[25:28]
# Out:
#    campaign_id            campaign_name     channel  start_date    end_date  \
# 25    CMP00026       Event Promotion Be  Influencer  2023-09-02  2025-02-11
# 26    CMP00027     Discount Offer Could  Influencer  2024-02-12  2025-01-30
# 27    CMP00028  Seasonal Campaign Dream       Radio  2023-09-10  2024-11-14
# 28    CMP00029      Brand Awareness Job       Radio  2023-10-08  2024-03-27
#
#       budget  leads_generated  conversion_rate    revenue     status  \
# 25  37133.25             1381             1.59   60796.25  Completed
# 26  36908.97             3247            11.25  145718.78    Ongoing
# 27  69064.20             1006             3.34    6812.16    Planned
# 28  93726.27              820             1.60   34871.00  Completed
#
#     impressions  clicks    ctr  engagement_score campaign_manager  notes
# 25       777997   21830   2.81              4.31     Sanjay Kumar    NaN
# 26       200041   21527  10.76              1.52     Rahul Sharma    NaN
# ...

# %%
df.loc[[5,10,20]]
# Out:
#    campaign_id              campaign_name        channel  start_date  \
# 5     CMP00006      Event Promotion Study          Email  2024-04-09
# 10    CMP00011  Event Promotion Direction  Search Engine  2023-12-04
# 20    CMP00021      Brand Awareness Prove  Search Engine  2023-10-30
#
#       end_date    budget  leads_generated  conversion_rate   revenue  \
# 5   2025-05-09  75780.58             1769             2.56  29237.08
# 10  2024-05-01  91126.34             3082             7.46  24073.62
# 20  2025-01-11  35556.57             3249             3.64  27656.22
#
#        status  impressions  clicks    ctr  engagement_score campaign_manager  \
# 5   Completed       645167   13607   2.11              8.40      Kiran Gupta
# 10    Planned       522430   47395   9.07              8.92      Meena Mehta
# 20    Ongoing        65820   49938  75.87              4.56       Ravi Patel
#
#     notes
# 5     NaN
# 10    NaN
# 20    NaN

# %%
# Q1. How would you retrieve the values of the campaign_name and campaign_manager columns for rows with indices 5, 10, and 20 from a DataFrame named df?

df.loc[[5,10,20], ["campaign_name", "campaign_manager"]]
# Out:
#                 campaign_name campaign_manager
# 5       Event Promotion Study      Kiran Gupta
# 10  Event Promotion Direction      Meena Mehta
# 20      Brand Awareness Prove       Ravi Patel

# %%
df.iloc[[5,10,20], [1,14]]
# Out:
#                 campaign_name campaign_manager
# 5       Event Promotion Study      Kiran Gupta
# 10  Event Promotion Direction      Meena Mehta
# 20      Brand Awareness Prove       Ravi Patel

# %%
# Given a DataFrame df, how would you retrieve the values of the columns "conversion_rate" and "status" for the specific rows with indices 100, 125, 135, 200, and 300?

df.loc[[100,125, 135, 200,300], ["conversion_rate", "status"]]
# Out:
#      conversion_rate     status
# 100             5.58    Ongoing
# 125             6.16    Planned
# 135             2.31  Completed
# 200            13.84    Ongoing
# 300             5.27  Completed

# %%
bar=df.loc[[100,125, 135, 200,300], ["conversion_rate", "status"]]
sns.barplot(x="status", y="conversion_rate",data=bar) 
plt.xlabel("conversion_rate")
plt.ylabel("status")
plt.title("Barplot")
plt.show()

# %%
box=df.loc[[100,125, 135, 200,300], ["conversion_rate", "status"]]
sns.boxplot(x="status", y="conversion_rate",data=box) 
plt.xlabel("conversion_rate")
plt.ylabel("status")
plt.title("Boxplot")
plt.show()

# %%
# How can you select specific rows with indices 100, 125, 135, 200, and 300, and only the columns at positions 7 and 12 from a DataFrame df?

df.iloc[[100,125, 135, 200,300], [7, 12]]
# Out:
#      conversion_rate    ctr
# 100             5.58  19.83
# 125             6.16  12.68
# 135             2.31   3.35
# 200            13.84   6.26
# 300             5.27  37.19

# %%
plot=df.iloc[[100,125, 135, 200,300], [7, 12]]
plt.plot(plot["conversion_rate"], plot["ctr"])
plt.xlabel("conversion_rate")
plt.ylabel("ctr")
plt.title("plot")
plt.show()

# %%
# Select specific rows but keep column by name
dis = df.loc[[100, 125, 135, 200, 300], ["ctr"]]

sns.displot (x="ctr", data=dis)
plt.show()

# %%
# How do you select specific rows with indices 450, 500, 572, 600, and 650 from a DataFrame df and display only the columns leads_generated and conversion_rate?

df.loc[[450,500,572,600,650], ["leads_generated", "conversion_rate"]]
# Out:
#      leads_generated  conversion_rate
# 450              357             3.07
# 500             2704            10.73
# 572             4968             5.42
# 600              415             3.12
# 650             4753             9.49

# %%
sca=df.loc[[450,500,572,600,650], ["leads_generated", "conversion_rate"]]
plt.scatter(sca["leads_generated"], sca["conversion_rate"])
plt.xlabel("leads_generated")
plt.ylabel("conversion_rate")
plt.title("Scatter")
plt.show()

# %%
# Q: Create a new column cost_per_lead by dividing the budget by leads_generated.
df["cost_per_lead"]=df["budget"]/df["leads_generated"]
df.head(3)
# Out:
#   campaign_id                 campaign_name        channel  start_date  \
# 0    CMP00001             Product Launch My  Search Engine  2023-06-02
# 1    CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2    CMP00003  Brand Awareness Relationship          Radio  2023-10-18
#
#      end_date    budget  leads_generated  conversion_rate    revenue  \
# 0  2024-08-17  53108.27             4022             7.41  140155.63
# 1  2025-07-29  27767.47             2997             0.79   22088.26
# 2  2024-01-12  30913.46             3638             9.00   90698.04
#
#       status  impressions  clicks    ctr  engagement_score campaign_manager  \
# 0  Completed       122958   35250  28.67              4.32       Ravi Kumar
# 1    Planned       672155   25921   3.86              4.33       Amit Mehta
# 2  Completed       132932   26760  20.13              1.47       Amit Mehta
#
#    notes  cost_per_lead
# 0    NaN      13.204443
# 1    NaN       9.265088
# ...

# %%
# Q: Extract only the campaign_name, budget, and revenue columns.

df[["campaign_name", "budget", "revenue"]].head(3)
# Out:
#                   campaign_name    budget    revenue
# 0             Product Launch My  53108.27  140155.63
# 1      Product Launch Candidate  27767.47   22088.26
# 2  Brand Awareness Relationship  30913.46   90698.04

# %%
# Q: Filter all campaigns where revenue is greater than 100,000.

df[(df["revenue"]>100000)].head(10)
# Out:
#    campaign_id              campaign_name        channel  start_date  \
# 0     CMP00001          Product Launch My  Search Engine  2023-06-02
# 6     CMP00007     Seasonal Campaign Year             TV  2023-07-14
# 18    CMP00019      Brand Awareness Adult      Newspaper  2024-04-07
# 19    CMP00020       Brand Awareness Rich     Influencer  2024-04-15
# 26    CMP00027       Discount Offer Could     Influencer  2024-02-12
# 29    CMP00030    Event Promotion Clearly  Search Engine  2023-12-07
# 31    CMP00032       Event Promotion Tell     Influencer  2024-03-03
# 34    CMP00035      Product Launch Father     Influencer  2024-03-19
# 38    CMP00039  Event Promotion Professor     Influencer  2023-07-10
# 40    CMP00041       Event Promotion Miss   Social Media  2024-02-10
#
#       end_date    budget  leads_generated  conversion_rate    revenue  \
# 0   2024-08-17  53108.27             4022             7.41  140155.63
# ...

# %%
# Q: Find campaigns managed by "Amit Mehta" that used the "Radio" channel.
df[(df["campaign_manager"]=="Amit Mehta") & (df["channel"]=="Radio")]
# Out:
#      campaign_id                 campaign_name channel  start_date  \
# 1       CMP00002      Product Launch Candidate   Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship   Radio  2023-10-18
# 1503    CMP01504           Discount Offer Page   Radio  2023-08-30
# 1507    CMP01508        Seasonal Campaign Ball   Radio  2024-05-23
# 1829    CMP01830  Seasonal Campaign Government   Radio  2023-11-09
# 2218    CMP02219   Seasonal Campaign Determine   Radio  2023-09-18
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# 1     2025-07-29  27767.47             2997             0.79   22088.26
# 2     2024-01-12  30913.46             3638             9.00   90698.04
# 1503  2025-04-26  85225.74             4687             7.73   98385.46
# 1507  2025-03-14   5770.78             3662             4.03  121176.45
# 1829  2025-01-04  74897.27             2545             5.80   77487.27
# ...

# %%
# Q: Count how many campaigns are in each status.

df["status"].value_counts()
sns.countplot(x="status",data=df)
plt.xlabel("status")
plt.show()

# %%
df.groupby("status")["campaign_id"].count()
# Out:
# status
# Completed    778
# Ongoing      712
# Planned      760
# Name: campaign_id, dtype: int64

# %%
# Q: Find the average budget and revenue grouped by channel.

df.groupby("channel")[["budget", "revenue"]].mean()
# Out:
#                      budget       revenue
# channel
# Email          51995.626859  71989.945562
# Influencer     50292.154832  75828.881101
# Newspaper      50836.444129  75110.727968
# Radio          50291.246602  67858.674466
# Search Engine  51422.882866  68733.514174
# Social Media   50691.997855  67294.895149
# TV             53055.825105  72643.822763

# %%
# Q: Sort campaigns by revenue in descending order.
df.sort_values("revenue", ascending=False)
# Out:
#      campaign_id              campaign_name        channel  start_date  \
# 1593    CMP01594  Seasonal Campaign Country             TV  2024-02-05
# 1701    CMP01702         Discount Offer Bar  Search Engine  2024-03-14
# 2207    CMP02208   Seasonal Campaign People          Radio  2023-11-29
# 1136    CMP01137        Event Promotion Now      Newspaper  2024-05-14
# 556     CMP00557       Product Launch Whole     Influencer  2024-03-07
# ...          ...                        ...            ...         ...
# 1306    CMP01307       Event Promotion Seem          Email  2023-07-09
# 33      CMP00034     Seasonal Campaign Time             TV  2023-06-14
# 1339    CMP01340       Brand Awareness Feel          Radio  2023-06-25
# 1733    CMP01734         Event Promotion If   Social Media  2024-02-26
# 1199    CMP01200       Discount Offer Those             TV  2024-01-25
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q: Sort campaigns first by status and then by budget within each status.

df.sort_values(["status", "budget"], ascending=False).head(5)
# Out:
#      campaign_id           campaign_name    channel  start_date    end_date  \
# 2189    CMP02190  Discount Offer Process  Newspaper  2024-01-27  2025-04-23
# 990     CMP00991  Brand Awareness Office      Email  2023-11-17  2024-04-08
# 1782    CMP01783   Brand Awareness Laugh  Newspaper  2024-01-27  2025-07-22
# 674     CMP00675  Product Launch Article      Email  2023-06-16  2024-09-15
# 1438    CMP01439      Brand Awareness So      Email  2023-12-09  2025-01-11
#
#         budget  leads_generated  conversion_rate    revenue   status  \
# 2189  99967.95             1758             7.48   33715.36  Planned
# 990   99639.78             4209             7.98  158838.00  Planned
# 1782  99525.12             1766             6.19   68975.36  Planned
# 674   99511.24              723             0.96   20651.18  Planned
# 1438  99481.11             4832            15.00  164163.52  Planned
#
#       impressions  clicks    ctr  engagement_score campaign_manager  notes  \
# ...

# %%
# Q: Find total leads_generated and revenue for each campaign_manager.
df.groupby("campaign_manager")[["leads_generated", "revenue"]].sum()
# Out:
#                   leads_generated     revenue
# campaign_manager
# Amit Chopra                 44287  1105116.86
# Amit Desai                  60694  1982750.41
# Amit Gupta                  56262  1498691.35
# Amit Joshi                  55910  1513785.21
# Amit Kumar                  70952  1828098.78
# ...                           ...         ...
# Vikram Mehta                55772  1752644.59
# Vikram Patel                66651  1825366.28
# Vikram Reddy                74989  2559960.41
# Vikram Sharma               37530  1109337.02
# Vikram Verma                75359  2461689.96
#
# [100 rows x 2 columns]

# %%
# Q: Get all campaigns with a revenue greater than 100,000.
df[(df["revenue"]>100000)]
# Out:
#      campaign_id             campaign_name        channel  start_date  \
# 0       CMP00001         Product Launch My  Search Engine  2023-06-02
# 6       CMP00007    Seasonal Campaign Year             TV  2023-07-14
# 18      CMP00019     Brand Awareness Adult      Newspaper  2024-04-07
# 19      CMP00020      Brand Awareness Rich     Influencer  2024-04-15
# 26      CMP00027      Discount Offer Could     Influencer  2024-02-12
# ...          ...                       ...            ...         ...
# 2221    CMP02222  Product Launch Community      Newspaper  2023-11-23
# 2227    CMP02228     Event Promotion Mouth      Newspaper  2024-05-18
# 2238    CMP02239       Discount Offer Also     Influencer  2023-12-17
# 2244    CMP02245    Brand Awareness Degree     Influencer  2024-02-27
# 2249    CMP02250   Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q: Find campaigns that used the "Social Media" channel.
df[(df["channel"]=="Social Media")]
# Out:
#      campaign_id             campaign_name       channel  start_date  \
# 3       CMP00004    Discount Offer Hundred  Social Media  2024-03-25
# 17      CMP00018   Brand Awareness Provide  Social Media  2024-01-30
# 35      CMP00036  Seasonal Campaign Entire  Social Media  2023-09-04
# 40      CMP00041      Event Promotion Miss  Social Media  2024-02-10
# 47      CMP00048   Seasonal Campaign Least  Social Media  2024-02-01
# ...          ...                       ...           ...         ...
# 2205    CMP02206     Seasonal Campaign Low  Social Media  2023-08-28
# 2208    CMP02209        Discount Offer Law  Social Media  2023-06-06
# 2215    CMP02216      Discount Offer Would  Social Media  2024-02-25
# 2217    CMP02218      Event Promotion Part  Social Media  2023-08-19
# 2236    CMP02237   Discount Offer Daughter  Social Media  2023-11-02
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q4: Filter campaigns where CTR is between 5 and 20.
df[(df["ctr"]>5) & (df["ctr"]<20)]
# Out:
#      campaign_id              campaign_name        channel  start_date  \
# 4       CMP00005       Event Promotion Help      Newspaper  2023-07-28
# 6       CMP00007     Seasonal Campaign Year             TV  2023-07-14
# 9       CMP00010       Product Launch Check          Radio  2023-06-09
# 10      CMP00011  Event Promotion Direction  Search Engine  2023-12-04
# 12      CMP00013       Event Promotion Late  Search Engine  2023-11-27
# ...          ...                        ...            ...         ...
# 2241    CMP02242     Seasonal Campaign High          Email  2024-03-06
# 2244    CMP02245     Brand Awareness Degree     Influencer  2024-02-27
# 2245    CMP02246       Brand Awareness Rate          Radio  2024-02-20
# 2248    CMP02249     Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250    Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q: Group by channel and calculate both mean revenue and mean CTR.
df.groupby("channel")[["revenue", "ctr"]].mean()
# Out:
#                     revenue        ctr
# channel
# Email          71989.945562   9.024928
# Influencer     75828.881101  13.326911
# Newspaper      75110.727968  12.564516
# Radio          67858.674466  11.777443
# Search Engine  68733.514174  12.315857
# Social Media   67294.895149  11.194059
# TV             72643.822763  11.509099

# %%
# Q: Drop all rows where the notes column is null.
df.dropna(subset=["notes"])
# Out:
# Empty DataFrame
# Columns: [campaign_id, campaign_name, channel, start_date, end_date, budget, leads_generated, conversion_rate, revenue, status, impressions, clicks, ctr, engagement_score, campaign_manager, notes, cost_per_lead]
# Index: []

# %%
# Q: Fill missing values in notes with "No comment".
df["notes"].replace(np.NaN, "No comment")
df
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q: Create ROI (return on investment) as revenue divided by budget.

df["return on investment"]=df["revenue"]/df["budget"]
df
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q: Sort campaigns by status and then budget descending within each status.
df.sort_values(["status", "budget"], ascending=False)
# Out:
#      campaign_id              campaign_name     channel  start_date  \
# 2189    CMP02190     Discount Offer Process   Newspaper  2024-01-27
# 990     CMP00991     Brand Awareness Office       Email  2023-11-17
# 1782    CMP01783      Brand Awareness Laugh   Newspaper  2024-01-27
# 674     CMP00675     Product Launch Article       Email  2023-06-16
# 1438    CMP01439         Brand Awareness So       Email  2023-12-09
# ...          ...                        ...         ...         ...
# 1220    CMP01221        Discount Offer Wife   Newspaper  2024-05-02
# 815     CMP00816      Brand Awareness About       Radio  2024-04-18
# 1154    CMP01155      Seasonal Campaign Day  Influencer  2024-05-13
# 2071    CMP02072  Event Promotion Treatment          TV  2023-07-04
# 170     CMP00171        Product Launch Pick       Radio  2023-11-05
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# 2189  2025-04-23  99967.95             1758             7.48   33715.36
# ...

# %%
# Q: Create a boolean column is_high_budget where the value is True if budget > 50,000.
df["is_high_budget"]=df["budget"]>50000
df
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...

# %%
# Q. Add a flag needs_followup for campaigns with status = "Ongoing" and CTR < 5

df["needs_followup"]=(df["status"]=="Ongoing") & (df["ctr"]<5)
df
# Out:
#      campaign_id                 campaign_name        channel  start_date  \
# 0       CMP00001             Product Launch My  Search Engine  2023-06-02
# 1       CMP00002      Product Launch Candidate          Radio  2024-01-26
# 2       CMP00003  Brand Awareness Relationship          Radio  2023-10-18
# 3       CMP00004        Discount Offer Hundred   Social Media  2024-03-25
# 4       CMP00005          Event Promotion Help      Newspaper  2023-07-28
# ...          ...                           ...            ...         ...
# 2245    CMP02246          Brand Awareness Rate          Radio  2024-02-20
# 2246    CMP02247          Discount Offer Think  Search Engine  2023-08-07
# 2247    CMP02248        Seasonal Campaign Role  Search Engine  2023-06-22
# 2248    CMP02249        Seasonal Campaign Open          Radio  2024-01-08
# 2249    CMP02250       Discount Offer Business             TV  2024-03-11
#
#         end_date    budget  leads_generated  conversion_rate    revenue  \
# ...
